# %% [markdown]
# # EF5 Output Analysis with Python

# %%
#matplotlib inline
from ef5_stats import make_stats_plot, parse_date

# %% [markdown]
# ## Lets make a time series plot of the full time series

# %%
make_stats_plot(r"output/ts.chhukha.crest.csv", "Example")

# %% [markdown]
# ## Lets zoom in on a specific period in the time series

# %%
make_stats_plot("ts.nzoia.crest.csv", "Nzoia 2004 AMJ", startTime=parse_date("2004-04-01 00:00"), endTime=parse_date("2004-07-01 00:00"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9d2cf106c82b> in <module>
# ----> 1 make_stats_plot("ts.nzoia.crest.csv", "Nzoia 2004 AMJ", startTime=parse_date("2004-04-01 00:00"), endTime=parse_date("2004-07-01 00:00"))
#
# ~/Share/Example/ef5_stats.py in parse_date(x)
#      15
#      16 def parse_date(x):
# ---> 17         return date2num(DT.datetime.strptime(x, "%m/%d/%Y %H:%M"))
#      18
#      19 def make_stats_plot(filename_in, plotTitle, startTime=0, endTime=0, forecastTime=0):
#
# ~/anaconda3/envs/SRI/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ...
